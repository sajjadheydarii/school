# %% [markdown]
# # **ِData Visualisation**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Input
years = [2015,2016,2017,2018,2019,2020,2021,2022]
Iran_dollar = [4,3.5,3,6,9,20,25,27]
KSA_dollar = [2,2.5,3,3.2,4,4,5,6]

#Making Plots
fig = plt.figure(figsize = (10,10))
plt.plot(years, Iran_dollar, color = "red")
plt.plot(years, KSA_dollar, color = "darkgreen", linestyle = "--")

#Some methods for better visualising
plt.xlabel("year")
plt.ylabel("dollar amount (calibrated in thousand tomans)")
plt.title("Iran vs KSA dollar difference in various years")
plt.legend(["Iran", "KSA"])
plt.yticks([j for j in range(1,32,3)])

#Annotate chart
plt.annotate("Iran and 5 + 1 negotiation",
             xytext = (2016,10),
             xy = (2017,3),
             fontsize = 13,
             arrowprops = dict(facecolor = "black", width = 2))

#Additional Codes
plt.grid()
plt.show()

# %%
days = [j for j in range(1,11)]
rain_values = [5,266,208,126,115,81,79,144,67,399]

fig = plt.figure(figsize = (8,8))
plt.bar(days, rain_values, color = "lightcoral")

plt.title("Rain quantity in 10 past days of a special city")
plt.xlabel("day")
plt.ylabel("rain value")
plt.xticks([k for k in range(1,11)])

plt.show()

# %%
days = [j for j in range(1,11)]
rain_values = [5,266,208,126,115,81,79,144,67,399]

fig = plt.figure(figsize = (8,8))
plt.barh(days, rain_values, color = "crimson")

plt.title("Rain quantity in 10 past days of a special city")
plt.ylabel("day")
plt.xlabel("rain value")
plt.yticks([k for k in range(1,11)])

plt.show()

# %%
x = np.random.normal(0,1,1024)
y = np.random.normal(0,1,1024)

fig = plt.figure(figsize = (8,8))
plt.scatter(x,y, color = "teal", s = 10)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Normal Distribution Scatter Plot")

plt.show()

# %%
import seaborn as sns

# %%
data = sns.load_dataset("tips")
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x = "day", y = "total_bill", data = data)

# %%
sns.catplot(x = "day", y = "total_bill", hue = "sex", data = data)

# %%
#Example
sns.catplot(x = "day", y = "total_bill", hue = "smoker", col = "sex",data = data)

# %%
sns.catplot(x = "day", y = "total_bill", hue = "time", data = data)

# %%
sns.catplot(x = "total_bill", y = "day", hue = "time", col = "sex", data = data)

# %%
sns.catplot(x = "total_bill", y = "day", hue = "time", kind = "box", data = data)

# %%
sns.catplot(x = "total_bill", y = "day", hue = "time", kind = "violin", data = data)

# %%
data1 = pd.read_csv("SmartPhones.csv")
data1
# Out:
#         Name        OS  Capacity  Ram  Weight    Company  inch
# 0  Galaxy S8   Android        64    4   149.0    Samsung   5.8
# 1  Lumia 950  windows         32    3   150.0  Microsoft   5.2
# 2  Xpreia L1   Android        16    2   180.0       Sony   5.5
# 3  iphone 7        ios       128    2   138.0      Apple   4.7
# 4    U Ultra   Android        64    4   170.0        HTC   5.7
# 5  Galaxy S5   Android        16    2   145.0    Samsung   5.1
# 6  iphone 5s       ios        32    1   112.0      Apple   4.0
# 7    Moto G5   Android        16    3   144.5   Motorola   5.0
# 8     Pixel    Android       128    4   143.0     Google   5.0

# %%
sns.pairplot(data1)

# %%
sns.pairplot(data1, hue = "OS")

# %%
sns.relplot(x = "total_bill", y = "tip", data = data)

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "time", data = data)

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "time", col = "day", data = data)

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "time", col = "sex", data = data)

# %%
sns.lmplot(x = "total_bill", y = "tip", hue = "time", col = "sex", data = data)

# %%
sns.jointplot(x = "total_bill", y = "tip", data = data)

# %%
sns.heatmap(data.iloc[:,[0,1,-1]].corr(), vmin = -1, vmax = 1, annot = True)

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.countplot(x = "day", data = data)
